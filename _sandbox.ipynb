# %%
import pandas as pd
import OpenFoodFacts_Data as off

# %%
off.get_OpenFoodFactsData('7613034232465')
# Out:
#                                        code  \
# _id                           7613034232465
# _keywords                     7613034232465
# additives                     7613034232465
# additives_debug_tags          7613034232465
# additives_n                   7613034232465
# additives_old_n               7613034232465
# additives_old_tags            7613034232465
# additives_original_tags       7613034232465
# additives_prev                7613034232465
# additives_prev_n              7613034232465
# additives_prev_original_tags  7613034232465
# additives_prev_tags           7613034232465
# additives_tags                7613034232465
# allergens                     7613034232465
# allergens_debug_tags          7613034232465
# allergens_from_ingredients    7613034232465
# allergens_from_user           7613034232465
# allergens_hierarchy           7613034232465
# allergens_tags                7613034232465
# amino_acids_prev_tags         7613034232465
# ...
